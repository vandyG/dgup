# %%
import polars as pl

# %%
usage_df = pl.read_parquet("data/silver/uta_gas_usage.parquet")

# %%
usage_df
# Out:
# shape: (3_410, 6)
# ┌────────────┬────────┬───────────┬───────────┬───────────┬─────────────┐
# │ Date       ┆ Nom    ┆ Delivery  ┆ Usage - 1 ┆ Usage - 2 ┆ Usage - 2_1 │
# │ ---        ┆ ---    ┆ ---       ┆ ---       ┆ ---       ┆ ---         │
# │ date       ┆ f64    ┆ f64       ┆ f64       ┆ f64       ┆ f64         │
# ╞════════════╪════════╪═══════════╪═══════════╪═══════════╪═════════════╡
# │ 2015-08-01 ┆ 1935.0 ┆ 1900.17   ┆ 36.12     ┆ 330.24    ┆ 0.0         │
# │ 2015-08-02 ┆ 1935.0 ┆ 1900.17   ┆ 137.26    ┆ 686.28    ┆ 0.0         │
# │ 2015-08-03 ┆ 1935.0 ┆ 1900.17   ┆ 158.93    ┆ 1529.42   ┆ 0.0         │
# │ 2015-08-04 ┆ 1935.0 ┆ 1900.17   ┆ 184.73    ┆ 1615.08   ┆ 0.0         │
# │ 2015-08-05 ┆ 1935.0 ┆ 1900.17   ┆ 209.5     ┆ 1543.87   ┆ 0.0         │
# │ …          ┆ …      ┆ …         ┆ …         ┆ …         ┆ …           │
# │ 2024-11-26 ┆ 1667.0 ┆ 1653.3306 ┆ 328.86    ┆ 1943.93   ┆ 11.48       │
# ...
